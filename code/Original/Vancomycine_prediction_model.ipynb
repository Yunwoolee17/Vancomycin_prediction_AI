# %% [markdown]
# #Install the libary

# %%
# !pip install mljar-supervised

# %% [markdown]
# #Loading the data

# %%
from google.colab import drive
import pandas as pd
drive.mount('/content/drive')

df_vanco = pd.read_csv('/content/drive/My Drive/data/Vancomycin_CRF_ver11.csv')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ## Make functions to changing the values

# %%
def age_normalization(age):
    if age < 0 or age > 112:
        raise ValueError("Age must be between 0 and 112")
    elif age < 13:
        return 0
    elif age <= 18:
        return 1
    elif age <= 29:
        return 2
    elif age <= 49:
        return 3
    elif age <= 64:
        return 4
    else:  # age >= 65
        return 5

def crcl_normalization(crcl):
  if crcl < 70:
    return 1
  else: #
    return 2

def eGFR_normalization(egfr):
  if egfr < 90:
    return 1
  else:
    return 2

def bun_normalization(bun):
  if bun <7:
    return 1
  else:
    return 2

def crp_normalization(crp):
  if crp> 10:
    return 1
  else: # normal
    return 2

def hb_normalization(hb,gender):
  if gender == 1: # Male
    if hb < 13.5:
      return 0
    elif hb > 17.5:
      return 1
    else:
      return 2
  else: # Female
    if hb < 12.5:
      return 0
    elif hb >15.5:
      return 1

def plt_normalization(plt):
  if plt <150: # 150000
    return 0
  elif plt >450:
    return 1
  else:
    return 2

def bmi_normalization(bmi):
  if bmi < 18.5:
    return 0
  elif bmi < 22.9:
    return 1
  elif bmi < 24.9:
    return 2
  elif bmi < 29.9:
    return 3
  else:
    return 4

# %% [markdown]
# ## Change the values in each column

# %%
df_vanco['Age'] = df_vanco['Age'].apply(age_normalization)
df_vanco['CrCl'] = df_vanco['CrCl'].apply(crcl_normalization)
df_vanco['BUN'] = df_vanco['BUN'].apply(bun_normalization)
df_vanco['CRP'] = df_vanco['CRP'].apply(crp_normalization)
df_vanco['Hb'] = df_vanco.apply(lambda row: hb_normalization(row['Hb'], row['Gender']), axis=1)
df_vanco['PLT'] = df_vanco['PLT'].apply(plt_normalization)
df_vanco['BMI'] = df_vanco['BMI'].apply(bmi_normalization)
df_vanco['eGFR'] = df_vanco['eGFR'].apply(eGFR_normalization)

# %% [markdown]
# #Separating data for model

# %%
from sklearn.model_selection import train_test_split

train_data, test_data = train_test_split(
    df_vanco, train_size=0.8, test_size=0.2, random_state=42
)

target = "Initial VCM_daily_dose"
X_train,y_train = train_data.drop([target],axis=1),train_data[target]
X_test,y_test = test_data.drop([target],axis=1),test_data[target]

# %% [markdown]
# #Model

# %%
from supervised.automl import AutoML
from sklearn.metrics import accuracy_score,mean_absolute_error,mean_squared_error,r2_score

# %% [markdown]
# ### Define the mode by setting parameters in AutoML

# %%
# Set a folder name to save trained models
result_path = 'AutoML_vacomycin'

# For more details for each parameters : https://supervised.mljar.com/features/modes/
automl = AutoML(results_path = result_path,
                mode="Perform",
                eval_metric = 'mae',
                train_ensemble=True,
                ml_task = 'regression',
                total_time_limit= 30* 60, #Each model will be trained for 30 minutes (30*60 seconds).
                golden_features = True,
                features_selection=True,
                explain_level = 2, # to obtain detailed explanation for each model
                random_state = 42)

# %%
automl.fit(X_train, y_train)
# Out:
# AutoML directory: AutoML_vacomycin
# The task is regression with evaluation metric mae
# AutoML will use algorithms: ['Linear', 'Random Forest', 'LightGBM', 'Xgboost', 'CatBoost', 'Neural Network']
# AutoML will ensemble available models
# AutoML steps: ['simple_algorithms', 'default_algorithms', 'not_so_random', 'golden_features', 'insert_random_feature', 'features_selection', 'hill_climbing_1', 'hill_climbing_2', 'ensemble']
# * Step simple_algorithms will try to check up to 1 model
# 1_Linear mae 296.412883 trained in 36.5 seconds (1-sample predict time 0.1652 seconds)
# * Step default_algorithms will try to check up to 5 models
# 2_Default_LightGBM mae 223.563143 trained in 21.49 seconds (1-sample predict time 0.0758 seconds)
# 3_Default_Xgboost mae 224.064282 trained in 24.6 seconds (1-sample predict time 0.0717 seconds)
# 4_Default_CatBoost mae 220.299873 trained in 6.3 seconds (1-sample predict time 0.0689 seconds)
# 5_Default_NeuralNetwork mae 261.108393 trained in 7.14 seconds (1-sample predict time 0.1286 seconds)
# 6_Default_RandomForest mae 219.467155 trained in 31.37 seconds (1-sample predict time 0.1301 seconds)
# * Step not_so_random will try to check up to 20 models
# /usr/local/lib/python3.10/dist-packages/shap/plots/_decision.py:90: UserWarning: Attempting to set identical low and high xlims makes transformation singular; automatically expanding.
# 11_LightGBM mae 231.919736 trained in 25.09 seconds (1-sample predict time 0.0654 seconds)
# 7_Xgboost mae 224.881602 trained in 28.16 seconds (1-sample predict time 0.1116 seconds)
# 15_CatBoost mae 221.098784 trained in 9.54 seconds (1-sample predict time 0.1195 seconds)
# 19_RandomForest mae 212.563101 trained in 31.36 seconds (1-sample predict time 0.1307 seconds)
# 23_NeuralNetwork mae 263.051668 trained in 9.95 seconds (1-sample predict time 0.1567 seconds)
# 12_LightGBM mae 229.126741 trained in 26.43 seconds (1-sample predict time 0.0662 seconds)
# 8_Xgboost mae 207.274766 trained in 27.49 seconds (1-sample predict time 0.0654 seconds)
# 16_CatBoost mae 222.232412 trained in 12.67 seconds (1-sample predict time 0.0679 seconds)
# 20_RandomForest mae 222.253249 trained in 40.46 seconds (1-sample predict time 0.1659 seconds)
# 24_NeuralNetwork mae 257.651267 trained in 13.64 seconds (1-sample predict time 0.1178 seconds)
# 13_LightGBM mae 224.326081 trained in 29.6 seconds (1-sample predict time 0.0677 seconds)
# 9_Xgboost mae 222.124133 trained in 32.33 seconds (1-sample predict time 0.099 seconds)
# 17_CatBoost mae 198.477086 trained in 18.3 seconds (1-sample predict time 0.1082 seconds)
# 21_RandomForest mae 216.050638 trained in 43.88 seconds (1-sample predict time 0.1575 seconds)
# 25_NeuralNetwork mae 279.452676 trained in 16.59 seconds (1-sample predict time 0.1803 seconds)
# 14_LightGBM mae 225.115952 trained in 35.17 seconds (1-sample predict time 0.0814 seconds)
# 10_Xgboost mae 215.304517 trained in 39.22 seconds (1-sample predict time 0.1206 seconds)
# 18_CatBoost mae 197.322151 trained in 20.46 seconds (1-sample predict time 0.0801 seconds)
# 22_RandomForest mae 212.35849 trained in 46.1 seconds (1-sample predict time 0.157 seconds)
# 26_NeuralNetwork mae 295.470245 trained in 20.98 seconds (1-sample predict time 0.1176 seconds)
# * Step golden_features will try to check up to 3 models
# None 10
# Add Golden Feature: Gender_ratio_Scr
# Add Golden Feature: Scr_ratio_Gender
# Add Golden Feature: Scr_multiply_Gender
# Add Golden Feature: BW_ratio_UA
# Add Golden Feature: UA_ratio_BW
# Add Golden Feature: Gender_ratio_Clvanco
# Add Golden Feature: Clvanco_ratio_UA
# Add Golden Feature: Age_diff_Albumin
# Add Golden Feature: Gender_ratio_PLT
# Add Golden Feature: CRP_sum_PLT
# Created 10 Golden Features in 1.27 seconds.
# 18_CatBoost_GoldenFeatures mae 195.28074 trained in 22.78 seconds (1-sample predict time 0.1478 seconds)
# 17_CatBoost_GoldenFeatures mae 197.829581 trained in 25.01 seconds (1-sample predict time 0.1029 seconds)
# 8_Xgboost_GoldenFeatures mae 206.570564 trained in 39.31 seconds (1-sample predict time 0.098 seconds)
# * Step insert_random_feature will try to check up to 1 model
# 18_CatBoost_GoldenFeatures_RandomFeature mae 194.427104 trained in 23.96 seconds (1-sample predict time 0.109 seconds)
# Drop features ['WBC', 'Scr_multiply_Gender', 'BW_ratio_UA', 'Clvanco_ratio_UA', 'UA_ratio_BW', 'Clvanco', 'Scr', 'Gender_ratio_Clvanco', 'Gender_ratio_Scr', 'TDM_AUC', 'Age', 'PLT', 'V_d', 'eGFR', 'CrCl', 'Gender_ratio_PLT', 'Age_diff_Albumin ', 'Hb', 'Gender', 'BUN', 'BMI', 'CRP', 'random_feature', 'CRP_sum_PLT', 'TP', 'Half-life', 'UA', 'Scr_ratio_Gender', 'Albumin ', 'K_e']
# * Step features_selection will try to check up to 5 models
# 18_CatBoost_GoldenFeatures_SelectedFeatures mae 195.182975 trained in 19.6 seconds (1-sample predict time 0.0678 seconds)
# 8_Xgboost_GoldenFeatures_SelectedFeatures mae 202.635707 trained in 27.54 seconds (1-sample predict time 0.0748 seconds)
# 22_RandomForest_SelectedFeatures mae 213.843306 trained in 31.32 seconds (1-sample predict time 0.0985 seconds)
# 2_Default_LightGBM_SelectedFeatures mae 223.831242 trained in 26.31 seconds (1-sample predict time 0.0378 seconds)
# 24_NeuralNetwork_SelectedFeatures mae 254.231629 trained in 21.23 seconds (1-sample predict time 0.0947 seconds)
# * Step hill_climbing_1 will try to check up to 14 models
# 27_CatBoost_GoldenFeatures_SelectedFeatures mae 187.743314 trained in 20.68 seconds (1-sample predict time 0.0918 seconds)
# 28_CatBoost_GoldenFeatures mae 193.828967 trained in 24.02 seconds (1-sample predict time 0.1028 seconds)
# 29_Xgboost_GoldenFeatures_SelectedFeatures mae 211.982558 trained in 28.51 seconds (1-sample predict time 0.0644 seconds)
# 30_Xgboost_GoldenFeatures mae 213.14022 trained in 41.5 seconds (1-sample predict time 0.1028 seconds)
# 31_RandomForest mae 211.69327 trained in 51.61 seconds (1-sample predict time 0.1533 seconds)
# 32_RandomForest mae 212.730412 trained in 50.17 seconds (1-sample predict time 0.1205 seconds)
# 33_RandomForest mae 212.368971 trained in 48.79 seconds (1-sample predict time 0.113 seconds)
# 34_RandomForest mae 223.554853 trained in 49.66 seconds (1-sample predict time 0.1718 seconds)
# 35_LightGBM mae 223.563143 trained in 43.84 seconds (1-sample predict time 0.0616 seconds)
# 36_LightGBM mae 223.563143 trained in 45.31 seconds (1-sample predict time 0.0628 seconds)
# 37_LightGBM_SelectedFeatures mae 223.831242 trained in 34.5 seconds (1-sample predict time 0.0632 seconds)
# 38_LightGBM_SelectedFeatures mae 223.831242 trained in 34.71 seconds (1-sample predict time 0.0382 seconds)
# 39_NeuralNetwork_SelectedFeatures mae 233.870858 trained in 27.87 seconds (1-sample predict time 0.1091 seconds)
# 40_NeuralNetwork mae 288.219397 trained in 30.94 seconds (1-sample predict time 0.111 seconds)
# * Step hill_climbing_2 will try to check up to 15 models
# 41_CatBoost_GoldenFeatures_SelectedFeatures mae 188.116521 trained in 28.72 seconds (1-sample predict time 0.0718 seconds)
# 42_CatBoost_GoldenFeatures_SelectedFeatures mae 190.869914 trained in 28.8 seconds (1-sample predict time 0.0662 seconds)
# 43_CatBoost_GoldenFeatures mae 195.150682 trained in 31.23 seconds (1-sample predict time 0.1187 seconds)
# 44_CatBoost_GoldenFeatures mae 189.323944 trained in 32.07 seconds (1-sample predict time 0.1867 seconds)
# 45_Xgboost_GoldenFeatures_SelectedFeatures mae 201.460967 trained in 34.94 seconds (1-sample predict time 0.0643 seconds)
# 46_Xgboost_GoldenFeatures mae 206.317753 trained in 48.94 seconds (1-sample predict time 0.1587 seconds)
# 47_RandomForest mae 213.351772 trained in 56.9 seconds (1-sample predict time 0.1785 seconds)
# * Step ensemble will try to check up to 1 model
# Ensemble mae 187.379119 trained in 8.65 seconds (1-sample predict time 0.1891 seconds)
# AutoML fit time: 1842.37 seconds
# AutoML best model: Ensemble
# AutoML(eval_metric='mae', explain_level=2, features_selection=True,
#        golden_features=True, ml_task='regression', mode='Perform',
#        random_state=42, results_path='AutoML_vacomycin', total_time_limit=1800)

# %% [markdown]
# The best modle is "Ensemble" and its mae is 187.379119.
#
# The details of Ensemble is in the folder "AutoML_vacomycin/Ensemble"

# %%
predictions = automl.predict_all(X_test)
predictions[:3]
# Out:
#     prediction
# 0  1982.200183
# 1  1993.732278
# 2  1995.447174

# %%
import numpy as np
df_result = pd.DataFrame()
df_result['true'] = y_test
df_result['prediction'] = predictions.values
df_result['accuracy'] = np.where(abs(df_result['true'] - df_result['prediction']) <= 250, 1, 0)
df_result[:3]
# Out:
#      true   prediction  accuracy
# 128  2000  1982.200183         1
# 45   2000  1993.732278         1
# 134  2000  1995.447174         1

# %%
print('R2:  ',r2_score(df_result['true'], df_result['prediction']))
print('MSE: ',mean_squared_error(df_result['true'],df_result['prediction']))
print('RMSE:',mean_squared_error(df_result['true'],df_result['prediction']) ** 0.5)
print('MAE: ',mean_absolute_error(df_result['true'],df_result['prediction']))
print('Accuracy: ', round(len(df_result.loc[df_result['accuracy'] == 1])/ len(df_result), 1))
# Out:
# R2:   0.11553997422576978
# MSE:  107568.21835537054
# RMSE: 327.9759417325767
# MAE:  226.90561528039973
# Accuracy:  0.5
